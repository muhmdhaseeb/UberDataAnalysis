# %% [markdown]
# #   UBER DATA ANALYSIS
#
# Uber Technologies, Inc., commonly known as Uber, is an American technology company. Its services include ride-hailing, food delivery, package delivery, couriers, freight transportation, and, through a partnership with Lime, electric bicycle and motorized scooter rental.
#
# In this tutorial, I will use Python to analyze data from Uber.
#
# I will use Python to:
#
# - Check how long do people travel with Uber?
# - What Hour Do Most People Take Uber To Their Destination?
# - Check The Purpose Of Trips
# - Which Day Has The Highest Number Of Trips
# - What Are The Number Of Trips Per Each Day?
# - What Are The Trips In The Month
# - The starting points of trips. Where Do People Start Boarding Their Trip From Most?

# %% [markdown]
# Import Libraries

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import calendar
import datetime

# %% [markdown]
# # Loading Dataset

# %%
df = pd.read_csv('uber.csv')
df.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %% [markdown]
# Check for missing values

# %% [markdown]
# If data is not available, Python uses NaN to represent it.
# Let's check below if datapoints missing in our dataset.

# %%
df.isnull().sum()
# Out:
# START_DATE*      0
# END_DATE*        1
# CATEGORY*        1
# START*           1
# STOP*            1
# MILES*           0
# PURPOSE*       503
# dtype: int64

# %% [markdown]
# Let's drop null values

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# START_DATE*    0
# END_DATE*      0
# CATEGORY*      0
# START*         0
# STOP*          0
# MILES*         0
# PURPOSE*       0
# dtype: int64

# %% [markdown]
# Let's check datatypes of columns

# %%
df.dtypes
# Out:
# START_DATE*     object
# END_DATE*       object
# CATEGORY*       object
# START*          object
# STOP*           object
# MILES*         float64
# PURPOSE*        object
# dtype: object

# %% [markdown]
# "START_DATE AND END_DATE" column should have date type. Let's convert them

# %%
df['START_DATE*'] = pd.to_datetime(df['START_DATE*'],format='%m/%d/%Y %H:%M')
df['END_DATE*'] = pd.to_datetime(df['END_DATE*'],format='%m/%d/%Y %H:%M')

# %%
df.head()
# Out:
#           START_DATE*           END_DATE* CATEGORY*           START*  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business      Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business      Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business      Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business      Fort Pierce
# 5 2016-01-06 17:15:00 2016-01-06 17:19:00  Business  West Palm Beach
#
#              STOP*  MILES*         PURPOSE*
# 0      Fort Pierce     5.1   Meal/Entertain
# 2      Fort Pierce     4.8  Errand/Supplies
# 3      Fort Pierce     4.7          Meeting
# 4  West Palm Beach    63.7   Customer Visit
# 5  West Palm Beach     4.3   Meal/Entertain

# %% [markdown]
# Now let's split START_DATE* column into:
# - Hour
# - Month
# - Day
# - Weekday

# %%
df['Hour'] = df['START_DATE*'].dt.hour
df['DAY'] = df['START_DATE*'].dt.day
df['MONTH'] = df['START_DATE*'].dt.month
df['WEEKDAY'] = df['START_DATE*'].dt.day_name()
df['YEAR'] = df['START_DATE*'].dt.year

# %%
df.head()
# Out:
#           START_DATE*           END_DATE* CATEGORY*           START*  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business      Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business      Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business      Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business      Fort Pierce
# 5 2016-01-06 17:15:00 2016-01-06 17:19:00  Business  West Palm Beach
#
#              STOP*  MILES*         PURPOSE*  Hour  DAY  MONTH    WEEKDAY  YEAR
# 0      Fort Pierce     5.1   Meal/Entertain    21    1      1     Friday  2016
# 2      Fort Pierce     4.8  Errand/Supplies    20    2      1   Saturday  2016
# 3      Fort Pierce     4.7          Meeting    17    5      1    Tuesday  2016
# 4  West Palm Beach    63.7   Customer Visit    14    6      1  Wednesday  2016
# 5  West Palm Beach     4.3   Meal/Entertain    17    6      1  Wednesday  2016

# %% [markdown]
# Let's see how many CATEGORIES are there in dataset

# %%
df['CATEGORY*'].value_counts()
# Out:
# Business    647
# Personal      6
# Name: CATEGORY*, dtype: int64

# %% [markdown]
# Now let's create countplot to show Category distribution

# %%
ax = sns.countplot(x=df['CATEGORY*'])
ax.set_title('TRAVEL CATEGORIES', fontsize=15)
ax.set_xlabel('Categories', fontsize=15)
ax.set_ylabel('Trip Counts', fontsize=15)
# Out:
# Text(0, 0.5, 'Trip Counts')

# %% [markdown]
# Let's find out how long people travel with uber

# %%
ax = df['MILES*'].plot.hist()
ax.set_xlabel("Mins")
# Out:
# Text(0.5, 0, 'Mins')

# %% [markdown]
# Above graph illustrate that most people travel for short period of time

# %% [markdown]
# Now let's see what hour do most people take Uber trip to Destination?

# %%
hours = df['Hour'].value_counts()
hours.plot(kind='bar',color='red',figsize=(10,5))
plt.xlabel('Hours')
plt.ylabel('Frequency')
plt.title('Number of trips Vs hours')
# Out:
# Text(0.5, 1.0, 'Number of trips Vs hours')

# %% [markdown]
# Above graph shows that at 1300 hrs (1pm) was the busiest hour and 0200 hrs (2am) is the quiet hour.

# %% [markdown]
# Now let's see the purpose of trip.

# %%
df['PURPOSE*'].value_counts().plot(kind='barh', color='green', figsize=(10,5))
plt.xlabel('Trip Purpose')
plt.ylabel('Count')
plt.title("Trip Purpse ")
# Out:
# Text(0.5, 1.0, 'Trip Purpse ')

# %% [markdown]
# Above graph shows that most people use Meeting and Meal/Entertain as their purpose of trip and commute is used for very less number of people

# %% [markdown]
# Now let's find out which day has the highest number of trips.

# %%
myexplode = [0.2, 0, 0, 0,0,0,0]
df['WEEKDAY'].value_counts().plot(kind='pie',autopct='%1.1f%%' ,shadow = True, explode = myexplode,figsize=(10,5))
plt.ylabel(' ')
plt.legend(df['WEEKDAY'], loc='best')
plt.axis('equal')
plt.title('Heighest Number of Trips Each Day')
# Out:
# (-1.118436304293846,
#  1.273642330005422,
#  -1.1077749827068821,
#  1.1487587343614798)

# %% [markdown]
# Above graph shows that Friday has the highest number of trips while Saturday has the lowest

# %% [markdown]
# Now let's find out number of trips each day

# %%
df['DAY'].value_counts().plot(kind='bar', color = 'brown', figsize = (10,5))
plt.xlabel('DAY')
plt.ylabel('Trip Count')
plt.title('Number of Trips Each Day')
# Out:
# Text(0.5, 1.0, 'Number of Trips Each Day')

# %% [markdown]
# Above graph shows that on 21st of every month people book uber ride the most while end of the month (31st) people least book uber ride

# %% [markdown]
# Now let's find out where do people start boarding their trips

# %%
df['START*'].value_counts().plot(kind='bar', color='brown', figsize=(25,10))
plt.title('Uber Trip Start Location')
# Out:
# Text(0.5, 1.0, 'Uber Trip Start Location')

# %% [markdown]
# Most people in this dataset starts their journey from Cary followed by some unknown location and then Morrisville.
